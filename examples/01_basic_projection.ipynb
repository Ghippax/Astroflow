# %%
# %load_ext autoreload
# %autoreload 2

import astroflow as af

#iso_ap_pth = "/sqfs/work/hp240141/z6b616/sims/arepoIso/cal1"

iso_pth = "/global/cfs/cdirs/agora/AGORA-DISK-repository-for-use/Grackle+noSF/"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
G3 = af.load("G3-ISO-AGORA-NSFF", iso_pth+"/GADGET-3/AGORA_ISO_LOW_DRY/snap_iso_dry_*")
#Changa = af.load("CHANGA-ISO-AGORA-NSFF", iso_pth+"/CHANGA/disklow/disklow.0*")
#Gasoline = af.load("GASOLINE-ISO-AGORA-NSFF", iso_pth+"/GASOLINE/LOW_dataset1*")
#Gear = af.load("GEAR-ISO-AGORA-NSFF", iso_pth+"/GEAR/snapshot_*", hint = "Swift")
Gizmo = af.load("GIZMO-ISO-AGORA-NSFF", iso_pth+"/GIZMO/snapshot_*")
# Out:
# yt : [INFO     ] 2025-10-14 09:32:42,804 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2025-10-14 09:32:42,805 Assuming length units are in kpc (physical)
# yt : [INFO     ] 2025-10-14 09:32:42,837 Parameters: current_time              = 0.0
# yt : [INFO     ] 2025-10-14 09:32:42,837 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2025-10-14 09:32:42,838 Parameters: domain_left_edge          = None
# yt : [INFO     ] 2025-10-14 09:32:42,838 Parameters: domain_right_edge         = None
# yt : [INFO     ] 2025-10-14 09:32:42,838 Parameters: cosmological_simulation   = False
# yt : [INFO     ] 2025-10-14 09:32:42,882 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2025-10-14 09:32:42,883 Assuming length units are in kpc (physical)
# yt : [INFO     ] 2025-10-14 09:32:42,918 Parameters: current_time              = 0.0
# yt : [INFO     ] 2025-10-14 09:32:42,919 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2025-10-14 09:32:42,919 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-10-14 09:32:42,920 Parameters: domain_right_edge         = [10000. 10000. 10000.]
# yt : [INFO     ] 2025-10-14 09:32:42,920 Parameters: cosmological_simulation   = False

# %%
G3 = af.load("G3-ISO-AGORA-NSFF")
# Out:
# yt : [INFO     ] 2025-10-14 09:32:43,984 Omega Lambda is 0.0, so we are turning off Cosmology.
# yt : [INFO     ] 2025-10-14 09:32:43,984 Assuming length units are in kpc (physical)
# yt : [INFO     ] 2025-10-14 09:32:44,017 Parameters: current_time              = 0.0
# yt : [INFO     ] 2025-10-14 09:32:44,017 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2025-10-14 09:32:44,018 Parameters: domain_left_edge          = None
# yt : [INFO     ] 2025-10-14 09:32:44,018 Parameters: domain_right_edge         = None
# yt : [INFO     ] 2025-10-14 09:32:44,018 Parameters: cosmological_simulation   = False
